# %%
import mysql.connector as connection
try:
    mydb = connection.connect(host="localhost", user="root", passwd="1234",use_pure=True)
    # check if the connection is established
    print(mydb.is_connected())

    query = "Create database  Attribute_DataSet;"
    cursor = mydb.cursor() #create a cursor to execute queries
    cursor.execute(query)
    print("Database Created!!")
    mydb.close()
except Exception as e:
    mydb.close()
    print(str(e))
# Out:
# True
# 1007 (HY000): Can't create database 'attribute_dataset'; database exists

# %% [markdown]
# ![Database_created.PNG](attachment:Database_created.PNG)

# %%
import mysql.connector as connection

try:
    mydb = connection.connect(host="localhost", database ='Attribute_DataSet',user="root", passwd="1234",use_pure=True)
    # check if the connection is established
    print(mydb.is_connected())

    query = "create table Attribute_DataSet(Dress_ID int(20),Style varchar(20),\
                Price varchar(20),Rating int(20),Size varchar(20),Season varchar(20),NeckLine varchar(20),\
                SleeveLength varchar(20),waiseline varchar(20),Material varchar(20),FabricType varchar(20),\
                Decoration varchar(20),`Pattern Type` varchar(20),Recommendation int(20))"

    cursor = mydb.cursor() #create a cursor to execute queries
    cursor.execute(query)
    print("Table Created!!")
    mydb.close()
except Exception as e:
    mydb.close()
    print(str(e))
# Out:
# True
# 1050 (42S01): Table 'attribute_dataset' already exists

# %% [markdown]
# ![Table_created.PNG](attachment:Table_created.PNG)

# %%
import mysql.connector as connection
try:
    mydb = connection.connect(host="localhost", user="root", passwd="1234",use_pure=True)
    # check if the connection is established
    print(mydb.is_connected())

    query = "Create database  Dress_Sales;"
    cursor = mydb.cursor() #create a cursor to execute queries
    cursor.execute(query)
    print("Database Created!!")
    mydb.close()
except Exception as e:
    mydb.close()
    print(str(e))
# Out:
# True
# 1007 (HY000): Can't create database 'dress_sales'; database exists

# %% [markdown]
# ![Dress_sales_datbase.PNG](attachment:Dress_sales_datbase.PNG)

# %%
import mysql.connector as connection
try:
    mydb = connection.connect(host="localhost", database =' Dress_Sales',user="root", passwd="1234",use_pure=True)
    # check if the connection is established
    print(mydb.is_connected())

    query = "create table Dress_Sales(Dress_ID int(20),`29/8/2013` int(20),`31/8/2013` int(20),\
            `09-02-2013` int(20),`09-04-2013` int(20), `09-06-2013` int(20),`09-08-2013` int(20),`09-10-2013` int(20),\
            `09-12-2013` int(20),`14/9/2013` int(20),`16/9/2013` int(20),`18/9/2013` int(20),`20/9/2013` int(20),\
            `22/9/2013`int(20),`24/9/2013` int(20),`26/9/2013` int(20),`28/9/2013` int(20) ,`30/9/2013`int(20),\
            `10-02-2013`int(20),`10-04-2013` int(20),`10-06-2013` int(20),`10-08-2010` int(20),`10-10-2013` int(20),\
            `10-12-2013` int(20))"

    cursor = mydb.cursor() #create a cursor to execute queries
    cursor.execute(query)
    print("Table Created!!")
    mydb.close()
    
except Exception as e:
    mydb.close()
    print(str(e))
# Out:
# True
# 1050 (42S01): Table 'dress_sales' already exists

# %% [markdown]
# ![Dress_sales_table.PNG](attachment:Dress_sales_table.PNG)

# %%
import mysql.connector as connection
mydb = connection.connect(host="localhost",database ='Attribute_DataSet',user="root", passwd="1234",use_pure=True)
# check if the connection is established
print(mydb.is_connected())

query = r'''
LOAD DATA INFILE "C://ProgramData//MySQL//MySQL Server 8.0//Uploads//Attribute_DataSet.txt"
INTO TABLE Attribute_DataSet
FIELDS TERMINATED BY ','
ENCLOSED BY '"'
LINES TERMINATED BY '\n'
IGNORE 1 ROWS;
'''
cursor = mydb.cursor() #create a cursor to execute queries
cursor.execute(query)
mydb.close()
# Out:
# True
# []

# %% [markdown]
# ![Bulk_load_attribute.PNG](attachment:Bulk_load_attribute.PNG)

# %%
# Dress Sales Bulk load 
#  https://github.com/Akshay-Kesarkar/sql/blob/main/loaddata.sql

# %% [markdown]
# ![dress_load.png](attachment:dress_load.png)

# %%
# 3. Read these datasets in pandas as dataframe?

# %%
pip install sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sqlalchemy
import mysql
import pymysql
import pandas as pd

# %%
engine = sqlalchemy.create_engine("mysql+pymysql://root:1234@localhost:3306/attribute_dataset")
data1 = pd.read_sql_table('attribute_dataset', engine)
data1
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low       5     M  Summer     o-neck
# 1    1212192089   Casual      Low       0     L  Summer     o-neck
# 2    1190380701  vintage     High       0     L  Automn     o-neck
# 3     966005983    Brief  Average       5     L  Spring     o-neck
# 4     876339541     cute      Low       5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low       5     M  Spring     o-neck
# 496   722565148     Sexy      Low       4  free  Summer     o-neck
# 497   532874347   Casual  Average       5     M  Summer     v-neck
# 498   655464934   Casual  Average       5     L  winter  boat-neck
# 499   919930954   Casual      Low       4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire           null     chiffon     ruffles
# ...

# %%
engine = sqlalchemy.create_engine("mysql+pymysql://root:1234@localhost:3306/dress_sales")
data2 = pd.read_sql_table('dress_sales', engine)
data2
# Out:
#        Dress_ID  29/8/2013  31/8/2013  09-02-2013  09-04-2013  09-06-2013  \
# 0    1006032852       2114       2274        2491        2660        2727
# 1    1212192089        151        275         570         750         813
# 2    1190380701          6          7           7           7           8
# 3     966005983       1005       1128        1326        1455        1507
# 4     876339541        996       1175        1304        1396        1432
# ..          ...        ...        ...         ...         ...         ...
# 495   713391965          0          0           0         560         554
# 496   722565148          0          0           0         875         866
# 497   532874347          0          0           0         734         728
# 498   655464934          0          0           0         254         259
# 499   919930954          0          0           0         538         545
#
#      09-08-2013  09-10-2013  09-12-2013  14/9/2013  ...  24/9/2013  26/9/2013  \
# ...

# %%
# 4. Convert attribute dataset in json format?

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\HP\Downloads\19.2.MySQL\19.2.MySQL\Attribute DataSet.csv')
df.to_json('Attibute.json')

# %%
# 5 store this data set in mongodb?

# %%
import json

# %%
with open(r'C:\Users\HP\Downloads\19.2.MySQL\19.2.MySQL\Attribute.json') as file:
    file_data1 = json.load(file)

# %%
import pymongo
client = pymongo.MongoClient("mongodb+srv://akshay:12345@cluster0.8prah.mongodb.net/?retryWrites=true&w=majority")
db = client.test
sales = client["data_sales_analytics"]
data_mongo = sales["attribute_dataset"]
data_mongo.insert_many([file_data1])

# %%
#manual method
#  https://github.com/Akshay-Kesarkar/pycharm/blob/master/mangotest1.py

# %% [markdown]
# ![pycharm.png](attachment:pycharm.png)

# %% [markdown]
# ![mongodb_upload.png](attachment:mongodb_upload.png)

# %%
#  6. in sql task try to perform left join operation with attrubute dataset and dress dataset on

# %%
import pandas as pd
import  sqlalchemy

import pymysql
import mysql.connector as conn
my = conn.connect(host ='localhost', user ='root' , passwd ='1234')
cur=my.cursor()
engine = sqlalchemy.create_engine("mysql+pymysql://root:1234@localhost:3306/attribute_dataset")
data1 = pd.read_sql_table('attribute_dataset', engine)
data1
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low       5     M  Summer     o-neck
# 1    1212192089   Casual      Low       0     L  Summer     o-neck
# 2    1190380701  vintage     High       0     L  Automn     o-neck
# 3     966005983    Brief  Average       5     L  Spring     o-neck
# 4     876339541     cute      Low       5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low       5     M  Spring     o-neck
# 496   722565148     Sexy      Low       4  free  Summer     o-neck
# 497   532874347   Casual  Average       5     M  Summer     v-neck
# 498   655464934   Casual  Average       5     L  winter  boat-neck
# 499   919930954   Casual      Low       4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire           null     chiffon     ruffles
# ...

# %%
import pandas as pd
import  sqlalchemy

import pymysql
import mysql.connector as conn
my = conn.connect(host ='localhost', user ='root' , passwd ='1234')
cur=my.cursor()
engine = sqlalchemy.create_engine("mysql+pymysql://root:1234@localhost:3306/attribute_dataset")
data1 = pd.read_sql_table('dress_sales1', engine)
data1
# Out:
#        Dress_ID  29/8/2013  31/8/2013  09-02-2013  09-04-2013  09-06-2013  \
# 0    1006032852       2114       2274        2491        2660        2727
# 1    1212192089        151        275         570         750         813
# 2    1190380701          6          7           7           7           8
# 3     966005983       1005       1128        1326        1455        1507
# 4     876339541        996       1175        1304        1396        1432
# ..          ...        ...        ...         ...         ...         ...
# 493   713391965          0          0           0         560         554
# 494   722565148          0          0           0         875         866
# 495   532874347          0          0           0         734         728
# 496   655464934          0          0           0         254         259
# 497   919930954          0          0           0         538         545
#
#      09-08-2013  09-10-2013  09-12-2013  14/9/2013  ...  24/9/2013  26/9/2013  \
# ...

# %%
combine = '''
SELECT *FROM attribute_dataset LEFT JOIN dress_sales1
ON attribute_dataset.Dress_ID=dress_sales1.Dress_ID;
'''
df = pd.read_sql_query(combine,engine)
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low       5     M  Summer     o-neck
# 1    1212192089   Casual      Low       0     L  Summer     o-neck
# 2    1190380701  vintage     High       0     L  Automn     o-neck
# 3     966005983    Brief  Average       5     L  Spring     o-neck
# 4     876339541     cute      Low       5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 545   722565148     Sexy      Low       4  free  Summer     o-neck
# 546   722565148     Sexy      Low       4  free  Summer     o-neck
# 547   532874347   Casual  Average       5     M  Summer     v-neck
# 548   655464934   Casual  Average       5     L  winter  boat-neck
# 549   919930954   Casual      Low       4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  ... 24/9/2013 26/9/2013 28/9/2013  \
# 0      sleevless    empire           null  ...    3554.0    3624.0    3706.0
# ...

# %%
k1=pd.set_option("display.max_columns", None)

# %%
import mysql.connector as conn
my = conn.connect(host ='localhost', user ='root' , passwd ='1234',database = 'attribute_dataset')
cur=my.cursor()

# %%
que = '''
 SELECT count(distinct(dress_sales1.Dress_ID))
 FROM attribute_dataset LEFT JOIN dress_sales1
 ON attribute_dataset.Dress_ID=dress_sales1.Dress_ID
'''
cur = my.cursor() 
cur.execute(que)
print(cur.fetchall())
# Out:
# [(473,)]

# %%
query = '''
 SELECT count(Recommendation)
 FROM attribute_dataset
 where Recommendation=0
'''
cur = my.cursor() 
cur.execute(query)
print(cur.fetchall())
# Out:
# [(290,)]

# %%
import mysql.connector as conn
my = conn.connect(host ='localhost', user ='root' , passwd ='1234',database = 'attribute_dataset')
cur=my.cursor()

# %%
query = '''
select Dress_ID,sum( 
`29/8/2013`+`31/8/2013`+ `09-02-2013`+ `09-04-2013`+ `09-06-2013`+`09-08-2013`+`09-10-2013`+`09-12-2013`+ `14/9/2013` +`16/9/2013` +`18/9/2013`+ `20/9/2013` +`22/9/2013`+`24/9/2013`+ `26/9/2013`+ `28/9/2013`+ `30/9/2013`+ `10-02-2013`+ `10-04-2013`+ `10-06-2013`+ `10-08-2010`+ `10-10-2013`+ `10-12-2013`) Total_sales from dress_sales1
group by Dress_ID
order by Total_sales desc
'''

pd.read_sql_query(query,engine)
# Out:
#        Dress_ID  Total_sales
# 0     629131530     155927.0
# 1     735635595      91556.0
# 2    1006032852      75979.0
# 3     749031896      75346.0
# 4     737538048      57543.0
# ..          ...          ...
# 468  1139064593         20.0
# 469   703395323         20.0
# 470   898316315         20.0
# 471  1124754999         19.0
# 472   907669618          4.0
#
# [473 rows x 2 columns]

# %%
query = '''
select Dress_ID,sum( 
`29/8/2013`+`31/8/2013`+ `09-02-2013`+ `09-04-2013`+ `09-06-2013`+`09-08-2013`+`09-10-2013`+`09-12-2013`+ `14/9/2013` +`16/9/2013` +`18/9/2013`+ `20/9/2013` +`22/9/2013`+`24/9/2013`+ `26/9/2013`+ `28/9/2013`+ `30/9/2013`+ `10-02-2013`+ `10-04-2013`+ `10-06-2013`+ `10-08-2010`+ `10-10-2013`+ `10-12-2013`) Total_sales from dress_sales1
group by Dress_ID
order by Total_sales desc limit 1 offset 2;
'''

pd.read_sql_query(query,engine)
# Out:
#      Dress_ID  Total_sales
# 0  1006032852      75979.0
